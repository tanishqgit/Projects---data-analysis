# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('D:\Training_latent_view\Interview - Problem Statement.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-f642391ecec9> in <module>
# ----> 1 df = pd.read_excel('D:\Training_latent_view\Interview - Problem Statement.xlsx')
#
# c:\python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\python\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
# ...

# %%
pip install xlrd
# Out:
# ...
#      ---------------------------------------- 96.5/96.5 KB 5.8 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.Installing collected packages: xlrd
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the 'c:\python\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_excel('D:\Training_latent_view\Interview - Problem Statement.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f642391ecec9> in <module>
# ----> 1 df = pd.read_excel('D:\Training_latent_view\Interview - Problem Statement.xlsx')
#
# c:\python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\python\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
# ...

# %%
df = pd.read_csv('Book1.csv')

# %%
df.head()
# Out:
#    #   id  quantity                  name item_type  price  vat_rate  \
# 0  1  181       1.0      Donut čokoládový         K   0.33        20
# 1  2  182       1.0        Nátierka Natur         K   0.79        20
# 2  3  183       1.0    Koktejl. paradajky         K   2.09        10
# 3  4  184       1.0      Trubičky-vanilk.         K   0.89        20
# 4  5  185       3.0  Rožok bez "E" - DA           K   0.07        10
#
#        product_category                 organization_name  \
# 0          pastry/sweet  Lidl Slovenská republika, v.o.s.
# 1          basic/spread  Lidl Slovenská republika, v.o.s.
# 2  fruits-veg/vegetable  Lidl Slovenská republika, v.o.s.
# 3          snacks/sweet  Lidl Slovenská republika, v.o.s.
# 4          pastry/basic  Lidl Slovenská republika, v.o.s.
#
#   organization_country  ...           issue_date         created_date  \
# 0            Slovensko  ...  30.01.2021 19:09:01  2021-04-21 19:44:26
# ...

# %%
df.head(10)
# Out:
#     #   id  quantity                  name item_type      price  vat_rate  \
# 0   1  181     1.000      Donut čokoládový         K   0.330000        20
# 1   2  182     1.000        Nátierka Natur         K   0.790000        20
# 2   3  183     1.000    Koktejl. paradajky         K   2.090000        10
# 3   4  184     1.000      Trubičky-vanilk.         K   0.890000        20
# 4   5  185     3.000  Rožok bez "E" - DA           K   0.070000        10
# 5   6  186     1.000     Gouda Old Holland         K   2.990000        20
# 6   7  187     0.111       Red Wine Cheese         K  14.864865        20
# 7   8  188     0.130       Red Wine Cheese         K  14.923077        20
# 8   9  189     2.000  Bravč.párky,200g             K   0.990000        20
# 9  10  190     3.000      Taštička pizzová         K   0.390000        20
#
#        product_category                 organization_name  \
# 0          pastry/sweet  Lidl Slovenská republika, v.o.s.
# ...

# %%
df.dtypes
# Out:
# #                              int64
# id                             int64
# quantity                     float64
# name                          object
# item_type                     object
# price                        float64
# vat_rate                       int64
# product_category              object
# organization_name             object
# organization_country          object
# organization_municipality     object
# organization_street           object
# organization_category         object
# unit_municipality             object
# unit_name                    float64
# unit_street                   object
# issue_date                    object
# created_date                  object
# last_modified_date            object
# tax_base_basic               float64
# tax_base_reduced             float64
# vat_rate_basic               float64
# vat_rate_reduced             float64
# fs_receipt_category           object
# user                           int64
# ...

# %%
df['created_date']
# Out:
# 0       2021-04-21 19:44:26
# 1       2021-04-21 19:44:26
# 2       2021-04-21 19:44:26
# 3       2021-04-21 19:44:26
# 4       2021-04-21 19:44:26
#                ...
# 8456    2022-03-30 15:01:12
# 8457    2022-03-30 15:01:12
# 8458    2022-03-30 15:01:19
# 8459    2022-03-30 15:01:19
# 8460    2022-03-30 15:01:19
# Name: created_date, Length: 8461, dtype: object

# %%
df['month'] = df['created_date'][5:7]

# %%
df.head()
# Out:
#    #   id  quantity                  name item_type  price  vat_rate  \
# 0  1  181       1.0      Donut čokoládový         K   0.33        20
# 1  2  182       1.0        Nátierka Natur         K   0.79        20
# 2  3  183       1.0    Koktejl. paradajky         K   2.09        10
# 3  4  184       1.0      Trubičky-vanilk.         K   0.89        20
# 4  5  185       3.0  Rožok bez "E" - DA           K   0.07        10
#
#        product_category                 organization_name  \
# 0          pastry/sweet  Lidl Slovenská republika, v.o.s.
# 1          basic/spread  Lidl Slovenská republika, v.o.s.
# 2  fruits-veg/vegetable  Lidl Slovenská republika, v.o.s.
# 3          snacks/sweet  Lidl Slovenská republika, v.o.s.
# 4          pastry/basic  Lidl Slovenská republika, v.o.s.
#
#   organization_country  ...         created_date   last_modified_date  \
# 0            Slovensko  ...  2021-04-21 19:44:26  2021-04-21 19:44:26
# ...

# %%
df['created_date']
# Out:
# 0       2021-04-21 19:44:26
# 1       2021-04-21 19:44:26
# 2       2021-04-21 19:44:26
# 3       2021-04-21 19:44:26
# 4       2021-04-21 19:44:26
#                ...
# 8456    2022-03-30 15:01:12
# 8457    2022-03-30 15:01:12
# 8458    2022-03-30 15:01:19
# 8459    2022-03-30 15:01:19
# 8460    2022-03-30 15:01:19
# Name: created_date, Length: 8461, dtype: object

# %%
df1 = []
for x in df['created_date']:
    df1.append(x[5:7])
df1
# Out:
# ['04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
#  '04',
# ...

# %%
df['month'] = df1

# %%
df.head()
# Out:
#    #   id  quantity                  name item_type  price  vat_rate  \
# 0  1  181       1.0      Donut čokoládový         K   0.33        20
# 1  2  182       1.0        Nátierka Natur         K   0.79        20
# 2  3  183       1.0    Koktejl. paradajky         K   2.09        10
# 3  4  184       1.0      Trubičky-vanilk.         K   0.89        20
# 4  5  185       3.0  Rožok bez "E" - DA           K   0.07        10
#
#        product_category                 organization_name  \
# 0          pastry/sweet  Lidl Slovenská republika, v.o.s.
# 1          basic/spread  Lidl Slovenská republika, v.o.s.
# 2  fruits-veg/vegetable  Lidl Slovenská republika, v.o.s.
# 3          snacks/sweet  Lidl Slovenská republika, v.o.s.
# 4          pastry/basic  Lidl Slovenská republika, v.o.s.
#
#   organization_country  ...         created_date   last_modified_date  \
# 0            Slovensko  ...  2021-04-21 19:44:26  2021-04-21 19:44:26
# ...

# %%
df.isnull().sum()
# Out:
# #                               0
# id                              0
# quantity                        0
# name                            0
# item_type                       0
# price                           0
# vat_rate                        0
# product_category                0
# organization_name               0
# organization_country            0
# organization_municipality       0
# organization_street             0
# organization_category         122
# unit_municipality             377
# unit_name                    8461
# unit_street                   377
# issue_date                      0
# created_date                    0
# last_modified_date              0
# tax_base_basic                 62
# tax_base_reduced              311
# vat_rate_basic                 62
# vat_rate_reduced              311
# fs_receipt_category           151
# user                            0
# transaction                     0
# month                           0
# dtype: int64

# %%
df_test = df.groupby('product_category').sum()
df_test.reset_index()
# Out:
#          product_category        #       id  quantity        price  vat_rate  \
# 0               auto/care    76458    86636    46.000    29.570000       300
# 1               auto/fuel    69966    80322   360.120    49.562802       260
# 2          baby/fake-food    32026    37046    12.000    10.110000       140
# 3               baby/food   675188   773788   132.000   176.810000      2120
# 4   baby/supplies-hygiene   337445   385125    89.000   180.580000      1210
# ..                    ...      ...      ...       ...          ...       ...
# 78           pastry/sweet   630634   721375   263.354   178.701034      2640
# 79                   pets   233488   266641    70.418   445.016024      1040
# 80               seasonal    16366    18399     6.000     1.490000        80
# 81           snacks/salty   495446   571106   267.842   180.382354      2420
# 82           snacks/sweet  3486693  4001203  1312.405  1040.923785     15520
#
# ...

# %%
df['organization_name'].nunique()
# Out:
# 188

# %%
df['organization_name'].unique()
# Out:
# array(['Lidl Slovenská republika, v.o.s.',
#        'Kaufland Slovenská republika v.o.s.', 'BILLA s.r.o.',
#        'TESCO STORES SR, a.s.', 'METRO Cash & Carry SR s. r. o.',
#        'COOP Jednota Galanta, spotrebné družstvo',
#        'PLAČEK PREMIUM, s. r. o.', 'OBI Slovakia s.r.o.',
#        'OMV Slovensko, s.r.o.', 'RRR Plus s. r. o.',
#        'BENU SK 43, s. r. o.', 'LAPLANT s.r.o.', 'Food express s.r.o.',
#        'Emil Krajčík, s.r.o.', 'TERNO real estate s.r.o.',
#        'Peter Vranovský FIPE', 'HORNBACH - Baumarkt SK spol. s r.o.',
#        'DAREX s.r.o.', 'Povega s. r. o.', 'TCHIBO SLOVENSKO spol. s r.o.',
#        'HAPPE s.r.o.', 'KARAKAM s. r. o.', 'BENU SK 21, s. r. o.',
#        'GECO, s. r. o.', 'Dušan Haba - Rozličný tovar',
#        'COOP Jednota Senica, spotrebné družstvo', 'Dr.Max 12 s.r.o.',
#        'SLOVNAFT, a.s.', 'CUKRÁREŇ LABUŽNÍK, s. r. o.',
#        'DALITRANS, s.r.o.', 'dm drogerie markt, s.r.o.',
# ...
