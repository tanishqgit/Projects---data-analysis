# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib. pyplot as plt

# %%
file = pd.read_csv('startup_funding.csv')

# %%
file.head()
# Out:
#                    Startup Name    Industry Vertical  \
# 0                        BYJU’S            Education
# 1                        Shuttl       Transportation
# 2                     Mamaearth            eCommerce
# 3  https://www.wealthbucket.in/              Finance
# 4                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bangalore
# 1              App based shuttle service       Gurugram
# 2  Retailer of baby and toddler products      Bangalore
# 3                      Online Investment          Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name     InvestmentnType  Amount in USD  year_funding  \
# 0    Tiger Global Management      Private Equity      200000000          2020
# 1  Susquehanna Growth Equity            Series C        8048394          2020
# ...

# %%
for i in range(2,10,2):
     print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
df = pd.DataFrame(file)

# %%
df
# Out:
#                      Startup Name    Industry Vertical  \
# 0                          BYJU’S            Education
# 1                          Shuttl       Transportation
# 2                       Mamaearth            eCommerce
# 3    https://www.wealthbucket.in/              Finance
# 4                          Fashor  Fashion and Apparel
# ..                            ...                  ...
# 982                     Power2SME    Consumer Internet
# 983                     Applicate           Technology
# 984          Zebi (yet to launch)           Technology
# 985                         Truce                 FMCG
# 986                         Qriyo    Consumer Internet
#
#                                            SubVertical City  Location  \
# 0                                           E-learning      Bangalore
# 1                            App based shuttle service       Gurugram
# 2                Retailer of baby and toddler products      Bangalore
# ...

# %%
sns.pointplot(x = df['month_funding'], y = df['Amount in USD'] , hue = df['year_funding'] ,markers = 'x',estimator = sum , ci = None)
# Out:
# c:\python\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.12156862745098039, 0.4666666666666667, 0.7058823529411765)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# c:\python\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# c:\python\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.17254901960784313, 0.6274509803921569, 0.17254901960784313)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# ...

# %%
demo_matrix = np.array(([13,35,74,48], [23,37,37,38],[73,39,93,39]))
demo_matrix[:, (1,2)]
# Out:
# array([[35, 74],
#        [37, 37],
#        [39, 93]])

# %%
demo_array=np.arange(0,10) 
demo_array
demo_array <3
#demo_array[demo_array <6]
#np.max(demo_array)
# Out:
# array([ True,  True,  True, False, False, False, False, False, False,
#        False])

# %%
df[df['Startup Name'] == 'BlackBuck']
# Out:
#    Startup Name Industry Vertical SubVertical City  Location  \
# 74    BlackBuck    Transportation   Logistics      Bangalore
#
#                                        Investors Name InvestmentnType  \
# 74  Goldman Sachs Investment Partners and Silicon ...        Series D
#
#     Amount in USD  year_funding  month_funding
# 74      150000000          2019              6

# %%
df['Startup Name'].unique()
# Out:
# array(['BYJU’S', 'Shuttl', 'Mamaearth', 'https://www.wealthbucket.in/',
#        'Fashor', 'Pando', 'Zomato', 'Ecozen', 'CarDekho', 'Dhruva Space',
#        'Rivigo', 'Healthians', 'Licious', 'Rein Games', 'Lenskart.com',
#        'Freshworks', 'Misters', 'Sunstone Eduversity Pvt. Ltd',
#        'Aye Finance', 'SuperGaming', 'Clumio', 'eBikeGo',
#        'Digital Mall Asia', 'Medikabazaar', 'Vogo Automotive', 'Paytm',
#        'Dunzo', 'FPL Technologies', 'Cashflo', 'Digital F5', '75F',
#        'Myelin Foundry', 'Atomberg Technology', 'GOQii', 'Vyapar App',
#        'Progcap', 'Alteria Capital', 'Pine Labs', 'Meesho', 'Cars24',
#        'Zendrive', 'Lo! Foods', 'Tala', 'INDwealth', 'HungerBox',
#        'AdmitKard', 'Grofers', 'Rapido Bike Taxi', 'RenewBuy', 'Atlan',
#        'WizCounsel', 'Uniphore', 'Daalchini Technologies',
#        '"BYJU\\\\\'S"', 'Moglix', 'Ezyhaul', 'Indus OS', 'HealthAssure',
#        'House of Msasaba', 'Board Infinity', 'NoBroker', 'Bira91',
# ...
